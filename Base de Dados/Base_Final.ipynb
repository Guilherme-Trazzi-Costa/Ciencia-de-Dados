# %%
import pandas as pd
import numpy as np

# %%
df_dengue = pd.read_excel("CasosDengue_Tratado.xlsx")
df_brasil = pd.read_excel("Limpa_Brasil_Tratado.xlsx")

# %%
display(df_brasil)
# Out:
#                                   Nome       Municipio       CEP  \
# 0        Paulo Sérgio Romancini Júnior        Campinas  13010091
# 1                     Eliane Odebrecht        Itanhaém  11740000
# 2   Patrícia De Castro Marques Sanfins         Itatiba  13252300
# 3                  Silviane Batistella         Jundiaí  13211410
# 4                 Silviane Batistella          Jundiaí  13211410
# 5                  Silviane Batistella         Jundiaí  13211410
# 6           Raryane Dos Santos Batista            Mauá   9321282
# 7           Maria De Fatima De Araújo     Pirassununga  13635000
# 8             Kelly Cristina Da Silva   Ribeirão Preto  14093000
# 9           Raryane Dos Santos Batista     Santo André   9121290
# 10     André Fabiano De Castro Vicente          Santos  11025020
# 11     André Fabiano De Castro Vicente          Santos  11025020
# 12            Alexandro Meiato Veratti       São Paulo   4195090
#
#    Ação realizada em  Peso total dos resíduos (kg)  \
# ...

# %%
display(df_dengue)
# Out:
#     dt_notificacao  ano_notificacao  mes_notificacao  cd_municipio  município  \
# 0       2022-01-01             2022                1        350950   Campinas
# 1       2022-02-01             2022                2        350950   Campinas
# 2       2022-03-01             2022                3        350950   Campinas
# 3       2022-04-01             2022                4        350950   Campinas
# 4       2022-05-01             2022                5        350950   Campinas
# ..             ...              ...              ...           ...        ...
# 325     2024-05-01             2024                5        355030  São Paulo
# 326     2024-06-01             2024                6        355030  São Paulo
# 327     2024-07-01             2024                7        355030  São Paulo
# 328     2024-08-01             2024                8        355030  São Paulo
# 329     2024-09-01             2024                9        355030  São Paulo
#
# ...

# %%
df_final = pd.merge(df_dengue,df_brasil,how= "outer")

display(df_final)
# Out:
#     dt_notificacao  ano_notificacao  mes_notificacao  cd_municipio  \
# 0       2022-01-01             2022                1        355030
# 1       2022-02-01             2022                2        355030
# 2       2022-03-01             2022                3        355030
# 3       2022-04-01             2022                4        355030
# 4       2022-05-01             2022                5        355030
# ..             ...              ...              ...           ...
# 424     2024-05-01             2024                5        354340
# 425     2024-06-01             2024                6        354340
# 426     2024-07-01             2024                7        354340
# 427     2024-08-01             2024                8        354340
# 428     2024-09-01             2024                9        354340
#
#           município       CEP  qntd_casos  qntd_hospitalizacao  \
# 0         São Paulo   4195090         215                   15
# ...

# %%
df_final.describe()
# Out:
#                       dt_notificacao  ano_notificacao  mes_notificacao  \
# count                            429       429.000000       429.000000
# mean   2023-05-02 01:27:16.363636480      2022.909091         6.090909
# min              2022-01-01 00:00:00      2022.000000         1.000000
# 25%              2022-09-01 00:00:00      2022.000000         3.000000
# 50%              2023-05-01 00:00:00      2023.000000         6.000000
# 75%              2024-01-01 00:00:00      2024.000000         9.000000
# max              2024-09-01 00:00:00      2024.000000        12.000000
# std                              NaN         0.793452         3.310086
#
#         cd_municipio           CEP     qntd_casos  qntd_hospitalizacao  \
# count     429.000000  4.290000e+02     429.000000           429.000000
# mean   353383.846154  1.154249e+07    2418.944056            75.389277
# min    350950.000000  4.195090e+06       0.000000             0.000000
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 27 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   dt_notificacao                             429 non-null    datetime64[ns]
#  1   ano_notificacao                            429 non-null    int64
#  2   mes_notificacao                            429 non-null    int64
#  3   cd_municipio                               429 non-null    int64
#  4   município                                  429 non-null    object
#  5   CEP                                        429 non-null    int64
#  6   qntd_casos                                 429 non-null    int64
#  7   qntd_hospitalizacao                        429 non-null    int64
#  8   qntd_resultado_soro                        429 non-null    int64
#  9   qntd_resultado_ns1                         429 non-null    int64
# ...

# %%
df_final.to_excel("Base_Final.xlsx", index=False)
